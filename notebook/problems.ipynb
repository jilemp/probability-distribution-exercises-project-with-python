# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# **Normal Distribution**

# %%
# TODO

from scipy.stats import norm

# Define all the probability functions related to this distribution

def dnorm(x, mean, std):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x, loc = mean, scale = std)

    return result

def pnorm(x, mean, std):
    """
    Calculates the cumulative of the normal distribution
    """
    result = norm.cdf(x, loc = mean, scale = std)

    return result

def qnorm(q, mean, std):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(q, loc = mean, scale = std)

    return result

def rnorm(mean, std, n):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc = mean, scale = std, size = n)

    return result

# %%
# Normal(10, 3) distribution functions
import numpy as np

np.random.seed(42)

print(f"Probability that a Normal(10, 3) takes the value 4: {dnorm(x = 4, mean = 10, std = 3)}")
print(f"Probability that a Normal(10, 3) will take a value less than 5: {pnorm(x = 5, mean = 10, std = 3)}")
print(f"Which value of a Nomal(10, 3) has a cumulative probability of 0.9? {qnorm(q = 0.9, mean = 10, std = 3)}")
print(f"Generate 2000 random values from a Normal(10, 3) distribution: {rnorm(mean = 10, std = 3, n = 2000)}")
# Out:
# Probability that a Normal(10, 3) takes the value 4: 0.017996988837729353
# Probability that a Normal(10, 3) will take a value less than 5: 0.0477903522728147
# Which value of a Nomal(10, 3) has a cumulative probability of 0.9? 13.844654696633802
# Generate 2000 random values from a Normal(10, 3) distribution: [11.49014246  9.5852071  11.94306561 ...  7.35437605  9.51079911
#   7.76529207]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

mean = 10
std = 3
data = rnorm(mean = 10, std = 3, n = 2000)

pdf = dnorm(data, mean = mean, std = std)
cdf = pnorm(data, mean = mean, std = std)
ppf = qnorm(data, mean = mean, std = std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Uniform Distribution**

# %%
from scipy.stats import uniform

# Define all the probability functions related to this distribution

def duniform(x, a, b):
    """
    Calculates the point estimate of the uniform distribution
    """
    result = uniform.pdf(x, loc = a, scale = b)

    return result

def puniform(x, a, b):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(x, loc = a, scale = b)

    return result

def quniform(q, a, b):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(q, loc = a, scale = b)

    return result

def runiform(a, b, n):
    """
    Generates random variables from the uniform distribution
    """
    result = uniform.rvs(loc = mean, scale = std, size = n)

    return result

# %%
# Uniform(10, 3) distribution functions
import numpy as np

np.random.seed(42)

print(f"Probability that a Uniform(10, 3) takes the value 10: {duniform(x = 10, a = 10, b = 3)}")
print(f"Probability that a Uniform(10, 3) will take a value less than 12: {puniform(x = 12, a = 10, b = 3)}")
print(f"Which value of a Uniform(10, 3) has a cumulative probability of 0.9? {quniform(q = 0.9, a = 10, b = 3)}")
print(f"Generate 2000 random values from a Uniform(10, 3) distribution: {runiform(a = 10, b = 3, n = 2000)}")
# Out:
# Probability that a Uniform(10, 3) takes the value 10: 0.3333333333333333
# Probability that a Uniform(10, 3) will take a value less than 12: 0.6666666666666666
# Which value of a Uniform(10, 3) has a cumulative probability of 0.9? 12.7
# Generate 2000 random values from a Uniform(10, 3) distribution: [11.12362036 12.85214292 12.19598183 ... 10.20687405 10.17116416
#  10.84656122]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

a = 10
b = 3
data = runiform(a = a, b = b, n = 2000)

pdf = duniform(data, a = a, b = b)
cdf = puniform(data, a = a, b = b)
ppf = quniform(data, a = a, b = b)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pdf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
